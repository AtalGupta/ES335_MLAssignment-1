# %%
# run usage.py 
# !python usage.py
# Out:
# Decision Tree Structure:
# ...
# ?(1 < -1.194)
# ├── Yes:
#     Predict: 2.720
# └── No:
#     ?(4 < 0.387)
#     ├── Yes:
#     │   ?(0 < 1.508)
#     │   ├── Yes:
#     │   │   ?(4 < -1.744)
#     │   │   ├── Yes:
#     │   │   │   ?(1 < 0.813)
#     │   │   │   ├── Yes:
#     │   │   │   │   Predict: 0.413
#     │   │   │   └── No:
#     │   │   │       Predict: 0.963
#     │   │   └── No:
#     │   │       ?(2 < 1.241)
#     │   │       ├── Yes:
#     │   │       │   Predict: -0.346
#     │   │       └── No:
#     │   │           Predict: 0.822
#     │   └── No:
#     │       ?(0 < 1.870)
#     │       ├── Yes:
#     │       │   Predict: 1.454
#     │       └── No:
#     │           Predict: 0.827
#     └── No:
#         ?(0 < -0.357)
#         ├── Yes:
#         │   ?(0 < -0.490)
#         │   ├── Yes:
#         │   │   ?(0 < -0.552)
#         │   │   ├── Yes:
#         │   │   │   Predict: 1.866
#         │   │   └── No:
#         │   │       Predict: 1.897
#         │   └── No:
# ...
